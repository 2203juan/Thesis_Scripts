# %% [markdown]
# # Script: 1.1 Rename-English-Dataset
# <h4><span style="color:blue">Juan José Hoyos Urcué</span></h4>

# %% [markdown]
# ### Dataset Upload

# %%
import pandas as pd
file_name = "cleaned.xlsx"
data = pd.read_excel(file_name, na_values = ["999.0","888.0","999","888"])

# %% [markdown]
# ### Spanish Variable names and number of variabes is shown

# %%
print(data.columns, len(data.columns))
# Out:
# Index(['eb_lc_sexo', 'eb_lc_etnia', 'edad', 'eb_lc_dpto_infeccion',
#        'eb_lc_peso', 'eb_lc_estatura', 'eb_lc_tiempo_evolucion',
#        'eb_lc_num_lc_activas', 'eb_lc_ejex_ulcera_mm_1',
#        'eb_lc_ejey_ulcera_mm_1', 'eb_lc_ulcera_area_1',
#        'eb_lc_ejex_lesion_mm_1', 'eb_lc_ejey_lesion_mm_1',
#        'eb_lc_lesion_area_1', 'eb_lc_tto_mcto_prescrito',
#        'eb_lc_tto_mcto_glucan_dosis', 'ef_lc_estado_final_estudio'],
#       dtype='object') 17

# %% [markdown]
# ### English Variable names is defined

# %%
english = [
    "gender", "ethnicity", "age", "infection_department",
    "weight", "height", "evolution_time", "number_active_injuries",
    "ulcer_horizontal", "ulcer_vertical", "ulcer_area", "injury_horizontal",
    "injury_vertical", "injury_area", "prescribed_medication", "glucantime_dosage",
    "cure_or_fail"]

# %% [markdown]
# ### English Variable names and number of variabes is shown

# %%
print(english, len(english))
# Out:
# ['gender', 'ethnicity', 'age', 'infection_department', 'weight', 'height', 'evolution_time', 'number_active_injuries', 'ulcer_horizontal', 'ulcer_vertical', 'ulcer_area', 'injury_horizontal', 'injury_vertical', 'injury_area', 'prescribed_medication', 'glucantime_dosage', 'cure_or_fail'] 17

# %% [markdown]
# ### Show a preview of the dataset before variables names change

# %%
data.head()
# Out:
#    eb_lc_sexo  eb_lc_etnia  edad eb_lc_dpto_infeccion  eb_lc_peso  \
# 0           1            1    22               Narino        58.6
# 1           2            2    19                Choco        59.0
# 2           1            1    20               Narino        62.0
# 3           2            1    18               Narino        77.0
# 4           1            2    35               Narino        53.9
#
#    eb_lc_estatura  eb_lc_tiempo_evolucion  eb_lc_num_lc_activas  \
# 0             176                       2                     1
# 1             145                       6                     1
# 2             158                       3                     6
# 3             163                       6                     6
# 4             158                       3                     1
#
#    eb_lc_ejex_ulcera_mm_1  eb_lc_ejey_ulcera_mm_1  eb_lc_ulcera_area_1  \
# 0                    11.6                     6.1                222.3
# ...

# %%
# variables names change is done

data.columns = english

# %% [markdown]
# ### Show a preview of the dataset after variables names change

# %%
data.head()
# Out:
#    gender  ethnicity  age infection_department  weight  height  \
# 0       1          1   22               Narino    58.6     176
# 1       2          2   19                Choco    59.0     145
# 2       1          1   20               Narino    62.0     158
# 3       2          1   18               Narino    77.0     163
# 4       1          2   35               Narino    53.9     158
#
#    evolution_time  number_active_injuries  ulcer_horizontal  ulcer_vertical  \
# 0               2                       1              11.6             6.1
# 1               6                       1              32.6            39.2
# 2               3                       6               7.0             4.2
# 3               6                       6               9.0             6.2
# 4               3                       1              11.8            10.0
#
#    ulcer_area  injury_horizontal  injury_vertical  injury_area  \
# ...

# %% [markdown]
# ### Save Dataset with new variables names

# %%
data.to_excel("cleaned_renamed.xlsx", index = False)
